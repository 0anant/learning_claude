# %%
from dotenv import load_dotenv
load_dotenv()

from anthropic import Anthropic
client = Anthropic()
model = "claude-sonnet-4-0"

# %%
def add_user_message(messages, text):
    user_message = {"role":"user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role":"assistant", "content": text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model = model,
        max_tokens = 1000,
        messages = messages,
    )
    return message.content[0].text

# %%
messages = []

while True:

    user_message = input("> ")
    print(">", user_message)
    

    add_user_message(messages, user_message)
    answer = chat(messages)

    add_assistant_message(messages, answer)

    print("----")
    print(answer)
    print("----")

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def assistant_user_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None, temperature = 1.0):
    params = {
        "model":model,
        "max_tokens":100,
        "messages":messages,
        "temperature":temperature
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

messages = []
user_message(messages, "What is the value of x in 2x+3=7?")
system = """You are patience maths tutor.You guide the student step by step without giving answers directly."""

answer = chat(messages,system, temperature = 1.0)
print(answer)

# %%
messages = []

system = "You are a senior python developer that writes very concise code."

add_user_message(messages, "write a python code for a that checks whether a given string is a palindrome or not?")

answer = chat(messages, system, temperture = 0)
